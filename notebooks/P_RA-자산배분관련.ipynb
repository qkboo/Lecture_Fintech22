# %% [markdown]
# # 로보어드바이저 / 자산배분

# %% [markdown]
# 현대 금융 이론을 기반으로한 자산배분 전략이 최근에도 유효-광범위 하게 사용
#
# ![image.png](attachment:c2eaace5-147d-47cd-974e-c3e70589f44d.png)
#  - https://www.linkedin.com/pulse/roboadvisors-like-commodore-vic20-apparently-according-raffaele-zenti

# %% [markdown]
# ### Deep Portfolid theory
#
# https://github.com/tcloaa/Deep-Portfolio-Theory

# %% [markdown]
# 인공지능을 활용한 분산투자 방법과 관련된 연구로 J.B.Heaton 등은 오토인코더를 사용하여 현재 판매되는 ETF 상품의 구성 종목들의 비율을 재조정하여 더 높은 수익률을 얻는 ETF 상품을 만드는 시스템에 대한 연구를 진행하였으며, 표본추출된 각 구간에 있어서 대부분의 경우 타겟 ETF 상품보다 높은 수익률을 확인 하였다. (2)
#
# 국내 2018년 유재필, 신현준은 J.B Heathon의 아이디어를국내 ETF 상품에 적용 효과성을 입증 (3) 단, 최종 펀드에 각 종목 변수가 몇%의 가중치로 구성되어 있는지 알기 어려워 투자자가 오토인코더로 만들어진 펀드를 실제로 구성하기 어렵다는 문제점을 지닌다

# %% [markdown]
# ### Deep financial Portfolio
#
# https://github.com/trident-dev/deep_financial_portfolios

# %% [markdown]
# # 참고
#
# 1. 딥러닝을 활용한 자산분배 시스템, https://koreascience.kr/article/JAKO201912937050956.pdf
# 1. Heaton, J. B., Polson, N. G., and Witte, J.H., “Deep Portfolio Theory,” University of Chicago, 2016.
#
#     - 한글 리뷰 https://sylim2357.github.io/paper%20review/deep-portfolio-theory-paper-review/
#
# 2. Ryu, J., Shin, H., “Portfolio Selection Strategy Using Deep Learning,” Journal of Information Technology and Architecture, Vol. 15, No. 1, pp. 43-50, 2018.
